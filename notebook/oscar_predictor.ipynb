# %% [markdown]
# # Erick Orozco
# # Date: 3-26-2022

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
nominated_df = pd.read_csv('..\data\known_data.csv')

target = pd.read_csv('../data/best_pic_win.csv')
target = target['Oscar_Best_Picture_won']
# Out:
#      Unnamed: 0  year                                              movie  \
# 0             4  2001  The Lord of the Rings: The Fellowship of the Ring
# 1            37  2003      The Lord of the Rings: The Return of the King
# 2            38  2002              The Lord of the Rings: The Two Towers
# 3            43  2000                                          Gladiator
# 4            50  2000                                            Traffic
# ..          ...   ...                                                ...
# 146        1305  2019                                     Marriage Story
# 147        1319  2019                                               1917
# 148        1340  2020                              Promising Young Woman
# 149        1341  2020                                          Nomadland
# 150        1343  2020                        Judas and the Black Messiah
#
#     certificate  duration                    genre  rate  metascore    votes  \
# ...
