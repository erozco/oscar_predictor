# %% [markdown]
# # Erick Orozco
# # Date: 3-26-2022

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# quick preprocessing 

df = pd.read_csv('..\data\known_data.csv')

df = df.replace(['No'],0)
df = df.replace(['Yes'],1)
#target = target['Oscar_Best_Picture_won']

df = df.sort_values(by=['year'])
train_df = df[df['year']<2017]
test_df = df[df['year']>2016]

x_train = train_df.drop(columns=['Oscar_Best_Picture_won'])
x_test = test_df.drop(columns=['Oscar_Best_Picture_won'])
y_train = train_df['Oscar_Best_Picture_won']
y_test = test_df['Oscar_Best_Picture_won']
# Out:
#      Unnamed: 0  year                           movie certificate  duration  \
# 3            43  2000                       Gladiator           R       155
# 4            50  2000                         Traffic           R       147
# 5            65  2000  Crouching Tiger, Hidden Dragon       PG-13       120
# 6            70  2000                 Erin Brockovich           R       131
# 9           122  2000                        Chocolat       PG-13       121
# ..          ...   ...                             ...         ...       ...
# 117        1119  2016                          Fences       PG-13       139
# 114        1114  2016              Hell or High Water           R       102
# 127        1233  2016                  Hidden Figures          PG       127
# 112        1108  2016                         Arrival       PG-13       116
# 106        1057  2016                   Hacksaw Ridge           R       139
#
# ...
